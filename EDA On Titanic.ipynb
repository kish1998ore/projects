# %%
import pandas as pd
import numpy as np
import matplotlib
from sklearn import preprocessing
import seaborn as sns

# %%
read = pd.read_csv('train.csv')
read
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
nal = read.isna().sum()
nal
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
read["Age"].mean()
# Out:
# 29.69911764705882

# %%
Var = read["Age"].fillna(value=29)

# %%
read["Age"] = data
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [14], in <cell line: 1>()
# ----> 1 read["Age"] = data
#
# NameError: name 'data' is not defined

# %%
data.isna().sum()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 data.isna().sum()
#
# NameError: name 'data' is not defined

# %%
read.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
read["Cabin"]
# Out:
# 0       NaN
# 1       C85
# 2       NaN
# 3      C123
# 4       NaN
#        ...
# 886     NaN
# 887     B42
# 888     NaN
# 889    C148
# 890     NaN
# Name: Cabin, Length: 891, dtype: object

# %%
pd.Categorical(read["Cabin"])
# Out:
# [NaN, 'C85', NaN, 'C123', NaN, ..., NaN, 'B42', NaN, 'C148', NaN]
# Length: 891
# Categories (147, object): ['A10', 'A14', 'A16', 'A19', ..., 'F38', 'F4', 'G6', 'T']

# %%
# Cpd.Drop(read["Cabin"])

# %%
Cabin = read.drop("Cabin",axis = 1)

# %%
Cabin.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Embarked         2
# dtype: int64

# %%
Cabin.dropna(axis = 0,inplace = True)

# %%
Cabin.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Name           0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Ticket         0
# Fare           0
# Embarked       0
# dtype: int64

# %%
Cabin
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
pd.Categorical(Cabin["Sex"])
# Out:
# ['male', 'female', 'female', 'female', 'male', ..., 'female', 'male', 'female', 'male', 'male']
# Length: 712
# Categories (2, object): ['female', 'male']

# %%
Cabin["Sex"].replace(['female', 'male'],[0,1],inplace = True)
Cabin
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 885          886         0       3
# 886          887         0       2
# 887          888         1       1
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name  Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    1  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...    0  38.0      1
# 2                               Heikkinen, Miss. Laina    0  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)    0  35.0      1
# 4                             Allen, Mr. William Henry    1  35.0      0
# ..                                                 ...  ...   ...    ...
# ...

# %%
data = Cabin.drop(['Name','Ticket'],axis = 1)

# %%
from sklearn import preprocessing

label_encoder = preprocessing.LabelEncoder()

data['Embarked'] = label_encoder.fit_transform(data['Embarked'])
data['Embarked'].value_counts()
# Out:
# 2    554
# 0    130
# 1     28
# Name: Embarked, dtype: int64

# %%
data.corr()
# Out:
#              PassengerId  Survived    Pclass       Sex       Age     SibSp  \
# PassengerId     1.000000  0.029526 -0.035609  0.024674  0.033681 -0.082704
# Survived        0.029526  1.000000 -0.356462 -0.536762 -0.082446 -0.015523
# Pclass         -0.035609 -0.356462  1.000000  0.150826 -0.365902  0.065187
# Sex             0.024674 -0.536762  0.150826  1.000000  0.099037 -0.106296
# Age             0.033681 -0.082446 -0.365902  0.099037  1.000000 -0.307351
# SibSp          -0.082704 -0.015523  0.065187 -0.106296 -0.307351  1.000000
# Parch          -0.011672  0.095265  0.023666 -0.249543 -0.187896  0.383338
# Fare            0.009655  0.266100 -0.552893 -0.182457  0.093143  0.139860
# Embarked       -0.001836 -0.181979  0.244145  0.109639 -0.032565  0.033064
#
#                 Parch      Fare  Embarked
# PassengerId -0.011672  0.009655 -0.001836
# Survived     0.095265  0.266100 -0.181979
# Pclass       0.023666 -0.552893  0.244145
# Sex         -0.249543 -0.182457  0.109639
# ...

# %%
sns.countplot(data['Embarked'],hue=data['Survived'])
plt.show()
# Out:
# C:\Users\DELL\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [30], in <cell line: 2>()
#       1 sns.countplot(data['Embarked'],hue=data['Survived'])
# ----> 2 plt.show()
#
# NameError: name 'plt' is not defined

# %%
sns.heatmap(data.corr())

# %%
data

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=100)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=0.3,random_state=100)
#
# NameError: name 'x' is not defined

# %%
from sklearn.metrics import accuracy_score

# %%
lr=LogisticRegression()
lr.fit(x_train,y_train)#sending data to train 70%
lrped=lr.predict(x_test)

# %%
accuracy_score(y_test,lrped)

# %%
from sklearn.model_selection import GridSearchCV

c_space = np.logspace(-5, 8, 15)
param_grid = {'C': c_space}

logreg_cv = GridSearchCV(lr, param_grid, cv = 5)

logreg_cv.fit(x_train,y_train)

print("Tuned Logistic Regression Parameter: {}".format(logreg.cv.best_params_))
print("Best Score Is {}".format(logreg_cv.best_score_))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [33], in <cell line: 6>()
#       3 c_space = np.logspace(-5, 8, 15)
#       4 param_grid = {'C': c_space}
# ----> 6 logreg_cv = GridSearchCV(lr, param_grid, cv = 5)
#       8 logreg_cv.fit(x_train,y_train)
#      10 print("Tuned Logistic Regression Parameter: {}".format(logreg.cv.best_params_))
#
# NameError: name 'lr' is not defined

# %% [markdown]
# # Comparison

# %%
read.isna().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age            177
# SibSp            0
# Parch            0
# Ticket           0
# Fare             0
# Cabin          687
# Embarked         2
# dtype: int64

# %%
read
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %%
data
# Out:
#      PassengerId  Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked
# 0              1         0       3    1  22.0      1      0   7.2500         2
# 1              2         1       1    0  38.0      1      0  71.2833         0
# 2              3         1       3    0  26.0      0      0   7.9250         2
# 3              4         1       1    0  35.0      1      0  53.1000         2
# 4              5         0       3    1  35.0      0      0   8.0500         2
# ..           ...       ...     ...  ...   ...    ...    ...      ...       ...
# 885          886         0       3    0  39.0      0      5  29.1250         1
# 886          887         0       2    1  27.0      0      0  13.0000         2
# 887          888         1       1    0  19.0      0      0  30.0000         2
# 889          890         1       1    1  26.0      0      0  30.0000         0
# 890          891         0       3    1  32.0      0      0   7.7500         1
#
# [712 rows x 9 columns]

# %%
data.isna().sum()
# Out:
# PassengerId    0
# Survived       0
# Pclass         0
# Sex            0
# Age            0
# SibSp          0
# Parch          0
# Fare           0
# Embarked       0
# dtype: int64

# %%
data.shape
# Out:
# (712, 9)
